# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# This code creates a virtual display to draw game images on. 
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1
# Out:
# Starting virtual X frame buffer: Xvfb.
# env: DISPLAY=:1

# %% [markdown]
# ### OpenAI Gym
#
# We're gonna spend several next weeks learning algorithms that solve decision processes. We are then in need of some interesting decision problems to test our algorithms.
#
# That's where OpenAI gym comes into play. It's a python library that wraps many classical decision problems including robot control, videogames and board games.
#
# So here's how it works:

# %%
import gym
env = gym.make("MountainCar-v0")
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation space: Box(2,)
# Action space: Discrete(3)

# %%
# draw game image.
# Note: this function does not work in coursera environment. 
# Please read week1/section1 about setting up course environment locally.
# You shouldn't be reading this if the course has already launched.
plt.imshow(env.render('rgb_array'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-c8639c1e855e> in <module>()
#       3 # Please read week1/section1 about setting up course environment locally.
#       4 # You shouldn't be reading this if the course has already launched.
# ----> 5 plt.imshow(env.render('rgb_array'))
#
# /opt/conda/lib/python3.6/site-packages/gym/core.py in render(self, mode)
#     282
#     283     def render(self, mode='human'):
# --> 284         return self.env.render(mode)
#     285
#     286     def close(self):
#
# /opt/conda/lib/python3.6/site-packages/gym/envs/classic_control/mountain_car.py in render(self, mode)
#      71
#      72         if self.viewer is None:
# ---> 73             from gym.envs.classic_control import rendering
#      74             self.viewer = rendering.Viewer(screen_width, screen_height)
#      75             xs = np.linspace(self.min_position, self.max_position, 100)
#
# /opt/conda/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in <module>()
#      21
#      22 try:
# ---> 23     from pyglet.gl import *
#      24 except ImportError as e:
#      25     reraise(prefix="Error occured while running `from pyglet.gl import *`",suffix="HINT: make sure you have OpenGL install. On Ubuntu, you can run 'apt-get install python-opengl'. If you're running on a server, you may need a virtual frame buffer; something like this should work: 'xvfb-run -s \"-screen 0 1400x900x24\" python <your_script.py>'")
#
# /opt/conda/lib/python3.6/site-packages/pyglet/gl/__init__.py in <module>()
#     237     # trickery is for circular import
#     238     _pyglet.gl = _sys.modules[__name__]
# --> 239     import pyglet.window
#
# /opt/conda/lib/python3.6/site-packages/pyglet/window/__init__.py in <module>()
#    1894 if not _is_pyglet_docgen:
#    1895     pyglet.window = sys.modules[__name__]
# -> 1896     gl._create_shadow_window()
#    1897
#
# /opt/conda/lib/python3.6/site-packages/pyglet/gl/__init__.py in _create_shadow_window()
#     206
#     207     from pyglet.window import Window
# --> 208     _shadow_window = Window(width=1, height=1, visible=False)
#     209     _shadow_window.switch_to()
#     210
#
# /opt/conda/lib/python3.6/site-packages/pyglet/window/xlib/__init__.py in __init__(self, *args, **kwargs)
#     164                     self._event_handlers[message] = func
#     165
# --> 166         super(XlibWindow, self).__init__(*args, **kwargs)
#     167
#     168         global _can_detect_autorepeat
#
# /opt/conda/lib/python3.6/site-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, display, screen, config, context, mode)
#     569         from pyglet import app
#     570         app.windows.add(self)
# --> 571         self._create()
#     572
#     573         self.switch_to()
#
# /opt/conda/lib/python3.6/site-packages/pyglet/window/xlib/__init__.py in _create(self)
#     261             self.canvas = XlibCanvas(self.display, self._view)
#     262
# --> 263             self.context.attach(self.canvas)
#     264             self.context.set_vsync(self._vsync) # XXX ?
#     265
#
# /opt/conda/lib/python3.6/site-packages/pyglet/gl/xlib.py in attach(self, canvas)
#     321         self.glx_window = glx.glXCreateWindow(
#     322             self.x_display, self.config._fbconfig, canvas.x_window, None)
# --> 323         self.set_current()
#     324
#     325     def set_current(self):
#
# /opt/conda/lib/python3.6/site-packages/pyglet/gl/xlib.py in set_current(self)
#     326         glx.glXMakeContextCurrent(
#     327             self.x_display, self.glx_window, self.glx_window, self.glx_context)
# --> 328         super(XlibContext13, self).set_current()
#     329
#     330     def detach(self):
#
# /opt/conda/lib/python3.6/site-packages/pyglet/gl/base.py in set_current(self)
#     299
#     300         # XXX
# --> 301         gl_info.set_active_context()
#     302         glu_info.set_active_context()
#     303
#
# /opt/conda/lib/python3.6/site-packages/pyglet/gl/gl_info.py in set_active_context(self)
#      96                                        c_char_p).value)
#      97             self.version = asstr(cast(glGetString(GL_VERSION), c_char_p).value)
# ---> 98             if self.have_version(3):
#      99                 from pyglet.gl.glext_arb import glGetStringi, GL_NUM_EXTENSIONS
#     100                 num_extensions = GLint()
#
# /opt/conda/lib/python3.6/site-packages/pyglet/gl/gl_info.py in have_version(self, major, minor, release)
#     168             return False
#     169         ver = '%s.0.0' % self.version.split(' ', 1)[0]
# --> 170         imajor, iminor, irelease = [int(v) for v in ver.split('.', 3)[:3]]
#     171         return imajor > major or \
#     172            (imajor == major and iminor > minor) or \
#
# /opt/conda/lib/python3.6/site-packages/pyglet/gl/gl_info.py in <listcomp>(.0)
#     168             return False
#     169         ver = '%s.0.0' % self.version.split(' ', 1)[0]
# --> 170         imajor, iminor, irelease = [int(v) for v in ver.split('.', 3)[:3]]
#     171         return imajor > major or \
#     172            (imajor == major and iminor > minor) or \
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# Note: if you're running this on your local machine, you'll see a window pop up with the image above. Don't close it, just alt-tab away.

# %% [markdown]
# ### Gym interface
#
# The three main methods of an environment are
# * __reset()__ - reset environment to initial state, _return first observation_
# * __render()__ - show current environment state (a more colorful version :) )
# * __step(a)__ - commit action __a__ and return (new observation, reward, is done, info)
#  * _new observation_ - an observation right after commiting the action __a__
#  * _reward_ - a number representing your reward for commiting action __a__
#  * _is done_ - True if the MDP has just finished, False if still in progress
#  * _info_ - some auxilary stuff about what just happened. Ignore it ~~for now~~.

# %%
obs0 = env.reset()
print("initial observation code:", obs0)

# Note: in MountainCar, observation is just two numbers: car position and velocity
# Out:
# initial observation code: [-0.44139686  0.        ]

# %%
print("taking action 2 (right)")
new_obs, reward, is_done, _ = env.step(2)

print("new observation code:", new_obs)
print("reward:", reward)
print("is game over?:", is_done)

# Note: as you can see, the car has moved to the riht slightly (around 0.0005)
# Out:
# taking action 2 (right)
# new observation code: [-4.41007149e-01  3.89715520e-04]
# reward: -1.0
# is game over?: False

# %% [markdown]
# ### Play with it
#
# Below is the code that drives the car to the right.
#
# However, it doesn't reach the flag at the far right due to gravity.
#
# __Your task__ is to fix it. Find a strategy that reaches the flag.
#
# You're not required to build any sophisticated algorithms for now, feel free to hard-code :)
#
# _Hint: your action at each step should depend either on __t__ or on __s__._

# %%
# create env manually to set time limit. Please don't change this.
TIME_LIMIT = 250
env = gym.wrappers.TimeLimit(gym.envs.classic_control.MountainCarEnv(),
                             max_episode_steps=TIME_LIMIT + 1)
s = env.reset()
actions = {'left': 0, 'stop': 1, 'right': 2}

# prepare "display"
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

def policy(t):
    if t<39:
        return actions['left']
    else:
        return actions['right']


for t in range(TIME_LIMIT):
    
    # change the line below to reach the flag
    s, r, done, _ = env.step(policy(t))
    print(s, t)
    
    #draw game image on display
    # ax.clear()
    # ax.imshow(env.render('rgb_array'))
    # fig.canvas.draw()
    
    if done:
        print("Well done!")
        break
else:    
    print("Time limit exceeded. Try again.")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# <img src="data:image/png;base64,..." width="432">
# [-5.85449220e-01 -5.42780508e-04] 0
# [-0.58653078 -0.00108156] 1
# [-0.58814315 -0.00161237] 2
# [-0.59027445 -0.0021313 ] 3
# [-0.59290902 -0.00263457] 4
# [-0.59602749 -0.00311848] 5
# [-0.59960702 -0.00357953] 6
# [-0.60362141 -0.00401439] 7
# [-0.60804138 -0.00441997] 8
# [-0.61283478 -0.0047934 ] 9
# [-0.61796688 -0.0051321 ] 10
# [-0.62340063 -0.00543375] 11
# [-0.629097   -0.00569637] 12
# [-0.63501528 -0.00591828] 13
# [-0.64111341 -0.00609813] 14
# [-0.64734832 -0.00623491] 15
# [-0.65367629 -0.00632796] 16
# [-0.66005324 -0.00637696] 17
# [-0.66643514 -0.00638189] 18
# [-0.67277824 -0.0063431 ] 19
# [-0.67903948 -0.00626123] 20
# [-0.6851767  -0.00613722] 21
# [-0.69114899 -0.00597229] 22
# [-0.69691691 -0.00576792] 23
# [-0.70244273 -0.00552582] 24
# [-0.4301357  -0.05213096] 98
# [-0.48395848 -0.05382278] 99
# [-0.53907787 -0.05511939] 100
# [-0.5950812  -0.05600334] 101
# [-0.65155252 -0.05647132] 102
# [-0.70808758 -0.05653506] 103
# [-0.76430854 -0.05622096] 104
# [-0.81987703 -0.0555685 ] 105
# [-0.87450469 -0.05462766] 106
# [-0.92796041 -0.05345572] 107
# [-0.98007439 -0.05211397] 108
# [-1.03073888 -0.05066449] 109
# [-1.07990641 -0.04916754] 110
# [-1.12758597 -0.04767956] 111
# [-1.17383789 -0.04625191] 112
# [-1.2  0. ] 113
# [-1.1987581  0.0012419] 114
# [-1.19427021  0.0044879 ] 115
# [-1.18652173  0.00774848] 116
# [-1.17548846  0.01103326] 117
# [-1.16113808  0.01435038] 118
# [-1.14343234  0.01770574] 119
# [-1.12233007  0.02110228] 120
# [-1.09779103  0.02453904] 121
# [-1.06978073  0.0280103 ] 122
# [-1.03827616  0.03150456] 123
# [-1.0032725   0.03500367] 124
# [-0.9647905   0.03848199] 125
# [-0.92288452  0.04190598] 126
# [-0.87765038  0.04523414] 127
# [-0.82923273  0.04841765] 128
# [-0.77783078  0.05140195] 129
# [-0.72370164  0.05412914] 130
# [-0.66716026  0.05654138] 131
# [-0.60857514  0.05858511] 132
# [-0.54835959  0.06021555] 133
# [-0.4869585   0.06140109] 134
# [-0.42483166  0.06212684] 135
# [-0.36243478  0.06239688] 136
# [-0.30020009  0.06223469] 137
# [-0.23851824  0.06168185] 138
# [-0.17772322  0.06079502] 139
# [-0.1180812   0.05964202] 140
# [-0.05978395  0.05829725] 141
# [-0.0029466   0.05683735] 142
# [0.05239085 0.05533745] 143
# [0.10625911 0.05386826] 144
# [0.15875332 0.05249421] 145
# [0.21002575 0.05127242] 146
# [0.26027822 0.05025247] 147
# [0.30975487 0.04947665] 148
# [0.35873547 0.0489806 ] 149
# [0.40752939 0.04879392] 150
# [0.45647027 0.04894088] 151
# [0.50591109 0.04944082] 152
# Well done!

# %% [markdown]
# ### Submit to coursera

# %%
from submit import submit_interface
submit_interface(policy, 'y2ee201@gmail.com', 'MeoWhdfEEeKvZ9nC')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-881293e98908> in <module>()
#       1 from submit import submit_interface
# ----> 2 submit_interface(policy, 'y2ee201@gmail.com', 'MeoWhdfEEeKvZ9nC')
#
# /home/jovyan/work/notebooks/week1_intro/submit.py in submit_interface(policy, email, token)
#      14
#      15     for t in range(TIME_LIMIT):
# ---> 16         s, r, done, _ = env.step(policy(t))
#      17         if done:
#      18             break
#
# <ipython-input-7-3df7c8a4b3fb> in policy(s)
#      14
#      15 def policy(s):
# ---> 16     if s[1]>0:
#      17         return actions['right']
#      18     else:
#
# TypeError: 'int' object is not subscriptable
